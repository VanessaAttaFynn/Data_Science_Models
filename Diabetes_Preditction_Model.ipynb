# %% [markdown]
# ## Loading Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv("diabetes.csv")
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %% [markdown]
# ## Checking for missing values

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#There are no null values in this dataset

# %%
df["Glucose"].unique()
#Notice that Glocuse has a value zero(O) which is impossible  for makes no sense
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
df['BloodPressure'].unique()
#Notice that BloodPressure has a value zero(0) which is impossible of makes no sense
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
df['SkinThickness'].unique()
#Notice that SkinThickness has a value zero(0) which cannot be that case
# Out:
# array([35, 29,  0, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31,
#        37, 42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40,
#        51, 56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
df['Insulin'].unique()
#Notice that Insulin has a value zero(0) which is impossible
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
# ...

# %%
df['BMI'].unique()
#Notice that BMI has a value of zero(0) which cannot be the case
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5,  0. , 37.6,
#        38. , 27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4,
#        39.8, 29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8,
#        19.9, 27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4,
#        27.4, 42. , 29.7, 28. , 39.1, 19.4, 24.2, 24.4, 33.7, 34.7, 23. ,
#        37.7, 46.8, 40.5, 41.5, 25. , 25.4, 32.8, 32.5, 42.7, 19.6, 28.9,
#        28.6, 43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4, 29.3, 24.6, 48.8,
#        32.4, 38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4, 28.7, 49.7, 39. ,
#        26.1, 22.5, 39.6, 29.5, 34.3, 37.4, 33.3, 31.2, 28.2, 53.2, 34.2,
#        26.8, 55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8, 36.9, 39.5,
#        27.3, 21.9, 40.6, 47.9, 50. , 25.2, 40.9, 37.2, 44.2, 29.9, 31.9,
#        28.4, 43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 30.4,
#        52.3, 24.3, 22.9, 34.8, 30.9, 40.1, 23.9, 37.5, 35.5, 42.8, 42.6,
# ...

# %%
# Hence we can conclude that the missing values are represented by zeros
# Or we may regard zeros in the above attributes as missing values

# %% [markdown]
# ## Handling Missing Values

# %%
attr = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
for i in attr:
    df[i].replace(0, df[i].mean(), inplace=True)

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# 0             6    148.0      72.000000      35.000000   79.799479  33.600000
# 1             1     85.0      66.000000      29.000000   79.799479  26.600000
# 2             8    183.0      64.000000      20.536458   79.799479  23.300000
# 3             1     89.0      66.000000      23.000000   94.000000  28.100000
# 4             0    137.0      40.000000      35.000000  168.000000  43.100000
# 5             5    116.0      74.000000      20.536458   79.799479  25.600000
# 6             3     78.0      50.000000      32.000000   88.000000  31.000000
# 7            10    115.0      69.105469      20.536458   79.799479  35.300000
# 8             2    197.0      70.000000      45.000000  543.000000  30.500000
# 9             8    125.0      96.000000      20.536458   79.799479  31.992578
# 10            4    110.0      92.000000      20.536458   79.799479  37.600000
# ...

# %%
#Missing values have now been replace my the mean of each column

# %% [markdown]
# ## Detecting Outliers

# %%
df.plot(kind='box', figsize=(12,12), layout=(3,3), subplots=True);

# %%
#Handling Outliers
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %%
df['Glucose'] = np.where(df['Glucose']>=140.250, 140.250, df['Glucose'])
df['BloodPressure'] = np.where(df['BloodPressure']>=80, 80, df['BloodPressure'])
df['SkinThickness'] = np.where(df['SkinThickness']>=32, 32, df['SkinThickness'])
df['Insulin'] = np.where(df['Insulin']>=127.250, 127.250, df['Insulin'])
df['BMI'] = np.where(df['BMI']>=36.60, 36.60, df['BMI'])
df['DiabetesPedigreeFunction'] = np.where(df['DiabetesPedigreeFunction']>=0.626250, 0.626250, df['DiabetesPedigreeFunction'])

# %%
df.plot(kind='box', figsize=(12,12), layout=(3,3), subplots=True);

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  115.665980      70.339442      24.580438   91.247403
# std       3.369578   21.213114       9.219440       6.169739   25.434347
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.062500      80.000000      32.000000  127.062500
# max      17.000000  140.250000      80.000000      32.000000  127.250000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.224503                  0.397068   33.240885    0.348958
# std      4.932123                  0.179068   11.760232    0.476951
# ...

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler().fit(df.drop(["Outcome"], axis=1))

x = ss.transform(df.drop(["Outcome"], axis=1))
y = df["Outcome"]

# %% [markdown]
# ## Data Visualization

# %%
histogram = df.hist(figsize = (20,20))

# %%
sns.pairplot(df, hue="Outcome",palette="husl")

# %%
# Correlation
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128955       0.221092       0.063708
# Glucose                      0.128955  1.000000       0.220973       0.132081
# BloodPressure                0.221092  0.220973       1.000000       0.128975
# SkinThickness                0.063708  0.132081       0.128975       1.000000
# Insulin                      0.022126  0.415494       0.016102       0.280853
# BMI                          0.072592  0.216341       0.244523       0.543741
# DiabetesPedigreeFunction    -0.021707  0.075905      -0.010462       0.096393
# Age                          0.544341  0.253776       0.332115       0.033985
# Outcome                      0.221898  0.449640       0.156172       0.175741
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.022126  0.072592                 -0.021707
# ...

# %%
# Heatmap
sns.heatmap(df.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %%
# From the heatmap we see that the corrention between the independent var and outcome is weak.
# The attribute with the strongest relationship with outcome is Age

# %% [markdown]
# ## Model Building

# %%
# The dataset must now be split into test and training set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=4)

# %% [markdown]
# ### 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

#Measuring Accurancy
lr = LogisticRegression()
model = lr.fit(x_train, y_train)
prediction = model.predict(x_test)

print("Acc. on trainig data: {:,.3f}".format(lr.score(x_train, y_train)))
print("Acc. on test data: {:,.3f}".format(lr.score(x_test, y_test)))
# Out:
# Acc. on trainig data: 0.733
# Acc. on test data: 0.763

# %% [markdown]
# ### 2. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(criterion='entropy',max_depth=4)
model1 = dtc.fit(x_train, y_train)
prediction1 = model1.predict(x_test)

print("Acc. on training data: {:,.3f}".format(dtc.score(x_train, y_train)))
print("Acc. on test data: {:,.3f}".format(dtc.score(x_test, y_test)))
# Out:
# Acc. on training data: 0.800
# Acc. on test data: 0.760

# %% [markdown]
# ### 3. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(criterion='entropy',max_depth=4)
model2 = rfc.fit(x_train, y_train)
prediction2 = model2.predict(x_test)
print("Acc. on training data: {:,.3f}".format(rfc.score(x_train, y_train)))
print("Acc. on test data: {:,.3f}".format(rfc.score(x_test, y_test)))
# Out:
# Acc. on training data: 0.835
# Acc. on test data: 0.802

# %% [markdown]
# ## Summary

# %%
models = pd.DataFrame({
    'Model': ['Logistic','Decision Tree Classifier','Random Forest Tree Classifier'],
    'Score': [ lr.score(x_test, y_test), dtc.score(x_test, y_test), rfc.score(x_test, y_test)]
})

models.sort_values(by = 'Score', ascending = True)
# Out:
#                            Model     Score
# 1       Decision Tree Classifier  0.759740
# 0                       Logistic  0.762987
# 2  Random Forest Tree Classifier  0.779221
